# %% [markdown]
# # Random Forest:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
import statistics

# %%
df1 = pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s9/emg_thumb_s9.csv')
print(df1.shape)
df1.head()
# Out:
# (20000, 8)
#           0         1         2         3         4         5         6  \
# 0  0.497236  0.487378  0.486597  0.489885  0.514627  0.492934  0.498531
# 1  0.497641  0.487752  0.486861  0.490034  0.514896  0.493082  0.498568
# 2  0.498044  0.488125  0.487125  0.490181  0.515166  0.493230  0.498606
# 3  0.498444  0.488497  0.487389  0.490328  0.515435  0.493377  0.498643
# 4  0.498840  0.488866  0.487652  0.490474  0.515703  0.493523  0.498680
#
#           7
# 0  0.472487
# 1  0.472814
# 2  0.473141
# 3  0.473465
# 4  0.473788

# %%
df2 = pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s9/kinematics_thumb_s9.csv')
print(df2.shape)
df2.head()
# Out:
# (20000, 69)
#            0          1          2         3          4          5         6  \
# 0  10.547117  72.248306 -72.571053 -0.290395  50.306685 -83.642419 -0.908432
# 1  10.556673  72.252170 -72.573840 -0.284922  50.310564 -83.641563 -0.908162
# 2  10.566146  72.256032 -72.576731 -0.279546  50.314453 -83.640720 -0.908184
# 3  10.575517  72.259886 -72.579726 -0.274285  50.318343 -83.639893 -0.908515
# 4  10.584767  72.263726 -72.582823 -0.269152  50.322227 -83.639084 -0.909167
#
#            7          8         9  ...         59         60         61  \
# 0  28.486734 -94.810614  2.798449  ... -34.007807  38.309516  27.118637
# 1  28.488005 -94.809459  2.789580  ... -34.007226  38.307178  27.115931
# 2  28.489288 -94.808239  2.780571  ... -34.006639  38.304834  27.113223
# 3  28.490580 -94.806951  2.771434  ... -34.006047  38.302486  27.110517
# 4  28.491878 -94.805594  2.762177  ... -34.005450  38.300139  27.107817
#
# ...

# %%
#####nan value check
df1.dropna(inplace=True)
df2.dropna(inplace=True)

# %%
#####input data partition
X_train, X_test, y_train, y_test = train_test_split(df1, df2, train_size=0.70, random_state=42)

print(f' Training input data size: {X_train.shape}')
print(f' Test input data size: {X_test.shape}')
print(f' Training output data size: {y_train.shape}')
print(f' Test output data size: {y_test.shape}')
# Out:
#  Training input data size: (14000, 8)
#  Test input data size: (6000, 8)
#  Training output data size: (14000, 69)
#  Test output data size: (6000, 69)

# %%
#####Random Forest regression
regressor = RandomForestRegressor(n_estimators=100,random_state=0)
start1=time.time()
regressor.fit(X_train,y_train)
end1=time.time()
regressor_pred_train = regressor.predict(X_train)
start2=time.time()
regressor_pred_test = regressor.predict(X_test)
end2=time.time()
regressor_accuracy = pd.DataFrame({
    'Parameters': ['R2_train','RMSE_train','R2_test','RMSE_test','time taken1','time taken2'],
    'regressor': [ r2_score(y_train,regressor_pred_train),mean_squared_error(y_train,regressor_pred_train,squared=False), 
                 r2_score(y_test,regressor_pred_test),mean_squared_error(y_test,regressor_pred_test,squared=False),(end1-start1)/98000,(end2-start2)/42000]})
regressor_accuracy=regressor_accuracy.transpose()
print(regressor_accuracy)
# Out:
#                    0           1         2          3            4  \
# Parameters  R2_train  RMSE_train   R2_test  RMSE_test  time taken1
# regressor   0.997671    0.333629  0.983861   0.876593     0.000378
#
#                       5
# Parameters  time taken2
# regressor      0.000011
