# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from scipy.io import loadmat
import pandas as pd
import numpy as np
data = loadmat('/content/drive/MyDrive/MTECH_PROJECT/s1/s1.mat')

# %%
print(data.keys())
print(type(data))
print(data)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'dsfilt_emg', 'finger_kinematics'])
# <class 'dict'>
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Sun Jan  5 13:50:07 2020', '__version__': '1.0', '__globals__': [], 'dsfilt_emg': array([[array([[0.47632609, 0.46844872, 0.50072618, ..., 0.52016162, 0.48122945,
#                 0.47287617],
#                [0.47635731, 0.46853975, 0.50092968, ..., 0.52250296, 0.48117326,
#                 0.47287558],
#                [0.47638829, 0.46863017, 0.50113238, ..., 0.52483156, 0.48111365,
#                 0.47287491],
#                ...,
#                [0.4769001 , 0.47040805, 0.50624306, ..., 0.58862823, 0.476423  ,
#                 0.47284067],
#                [0.4769001 , 0.47040805, 0.50624306, ..., 0.5886281 , 0.476423  ,
#                 0.47284067],
#                [0.4769001 , 0.47040805, 0.50624306, ..., 0.58862807, 0.476423  ,
# ...

# %%
s2_Kinematics=data['finger_kinematics']
data1=pd.DataFrame(s2_Kinematics)
print(data1)
# Out:
#                                                    0  \
# 0  [[105.90756790109839, 5.705859102398453, 15.39...
# 1  [[105.9322109338258, 7.789508904618028, 16.110...
# 2  [[103.5050453324182, 6.644271073382579, 19.908...
# 3  [[105.88872070566606, 6.198623554452773, 15.95...
# 4  [[105.76083197409193, 5.523045025820325, 16.63...
#
#                                                    1  \
# 0  [[104.81820837700194, 8.675858198795652, 15.70...
# 1  [[98.15549313025095, 6.4220244692664945, 24.93...
# 2  [[102.59468289697242, 7.368712424651472, 20.07...
# 3  [[103.60689292020618, 7.575006889270441, 18.89...
# 4  [[104.1659547506686, 7.863108018383242, 18.880...
#
#                                                    2  \
# 0  [[103.33959265294683, 8.572287564052228, 19.81...
# 1  [[102.59679415147473, 7.806558294458805, 18.88...
# 2  [[104.24995589986978, 6.380017733759372, 17.66...
# 3  [[101.41402595902676, 6.880968567787664, 22.18...
# ...

# %%
section1=(s2_Kinematics[0,0])

# %%
section8=(s2_Kinematics[1,0])

# %%
section15=(s2_Kinematics[2,0])

# %%
section22=(s2_Kinematics[3,0])

# %%
section29=(s2_Kinematics[4,0])

# %%
d2_thumb=np.concatenate((section1,section8,section15,section22,section29),axis=0)
print(d2_thumb.shape)
# Out:
# (20000, 69)

# %%
df2_thumb=pd.DataFrame(d2_thumb)
print(df2_thumb)
# Out:
#                0         1          2          3          4         5   \
# 0      105.907568  5.705859  15.394825  98.639977 -13.239525  7.595416
# 1      105.905120  5.705204  15.384618  98.641172 -13.245461  7.591911
# 2      105.902672  5.704482  15.374783  98.642337 -13.251386  7.588689
# 3      105.900227  5.703691  15.365345  98.643469 -13.257289  7.585763
# 4      105.897789  5.702831  15.356333  98.644567 -13.263162  7.583149
# ...           ...       ...        ...        ...        ...       ...
# 19995  103.927428  6.665537  17.037717  96.892977 -12.554991  9.026578
# 19996  103.927181  6.665179  17.038875  96.892707 -12.555262  9.027409
# 19997  103.926979  6.664890  17.039811  96.892487 -12.555484  9.028085
# 19998  103.926818  6.664660  17.040554  96.892311 -12.555661  9.028624
# 19999  103.926693  6.664481  17.041130  96.892174 -12.555800  9.029043
#
#               6          7         8          9   ...        59         60  \
# ...

# %%
df2_thumb.to_csv('/content/drive/MyDrive/MTECH_PROJECT/kinematics_thumb_s1.csv',index=False)

# %%
section2=(s2_Kinematics[0,1])

# %%
section9=(s2_Kinematics[1,1])

# %%
section16=(s2_Kinematics[2,1])

# %%
section23=(s2_Kinematics[3,1])

# %%
section30=(s2_Kinematics[4,1])

# %%
d2_index=np.concatenate((section2,section9,section16,section23,section30),axis=0)
print(d2_index.shape)
# Out:
# (20000, 69)

# %%
df2_index=pd.DataFrame(d2_index)

# %%
df2_index.to_csv('/content/drive/MyDrive/MTECH_PROJECT/kinematics_index_s1.csv',index=False)

# %%
section3=(s2_Kinematics[0,2])

# %%
section10=(s2_Kinematics[1,2])

# %%
section17=(s2_Kinematics[2,2])

# %%
section24=(s2_Kinematics[3,2])

# %%
section31=(s2_Kinematics[4,2])

# %%
d2_middle=np.concatenate((section3,section10,section17,section24,section31),axis=0)
print(d2_middle.shape)
# Out:
# (20000, 69)

# %%
df2_middle=pd.DataFrame(d2_middle)

# %%
df2_middle.to_csv('/content/drive/MyDrive/MTECH_PROJECT/kinematics_middle_s1.csv',index=False)

# %%
section4=(s2_Kinematics[0,3])

# %%
section11=(s2_Kinematics[1,3])

# %%
section18=(s2_Kinematics[2,3])

# %%
section25=(s2_Kinematics[3,3])

# %%
section32=(s2_Kinematics[4,3])

# %%
d2_ring=np.concatenate((section4,section11,section18,section25,section32),axis=0)
print(d2_ring.shape)
# Out:
# (20000, 69)

# %%
df2_ring=pd.DataFrame(d2_ring)

# %%
df2_ring.to_csv('/content/drive/MyDrive/MTECH_PROJECT/kinematics_ring_s1.csv',index=False)

# %%
section5=(s2_Kinematics[0,4])

# %%
section12=(s2_Kinematics[1,4])

# %%
section19=(s2_Kinematics[2,4])

# %%
section26=(s2_Kinematics[3,4])

# %%
section33=(s2_Kinematics[4,4])

# %%
d2_little=np.concatenate((section5,section12,section19,section26,section33),axis=0)
print(d2_little.shape)
# Out:
# (20000, 69)

# %%
df2_little=pd.DataFrame(d2_little)

# %%
df2_little.to_csv('/content/drive/MyDrive/MTECH_PROJECT/kinematics_little_s1.csv',index=False)

# %%
section6=(s2_Kinematics[0,5])

# %%
section13=(s2_Kinematics[1,5])

# %%
section20=(s2_Kinematics[2,5])

# %%
section27=(s2_Kinematics[3,5])

# %%
section34=(s2_Kinematics[4,5])

# %%
d2_all=np.concatenate((section6,section13,section20,section27,section34),axis=0)
print(d2_all.shape)
# Out:
# (20000, 69)

# %%
df2_all=pd.DataFrame(d2_all)

# %%
df2_all.to_csv('/content/drive/MyDrive/MTECH_PROJECT/kinematics_all_s1.csv',index=False)

# %%
section7=(s2_Kinematics[0,6])

# %%
section14=(s2_Kinematics[1,6])

# %%
section21=(s2_Kinematics[2,6])

# %%
section28=(s2_Kinematics[3,6])

# %%
section35=(s2_Kinematics[4,6])

# %%
d2_random=np.concatenate((section7,section14,section21,section21,section35),axis=0)
print(d2_random.shape)
# Out:
# (20000, 69)

# %%
df2_random=pd.DataFrame(d2_random)

# %%
df2_random.to_csv('/content/drive/MyDrive/MTECH_PROJECT/kinematics_random_s1.csv',index=False)
