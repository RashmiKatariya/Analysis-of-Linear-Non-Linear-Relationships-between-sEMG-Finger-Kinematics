# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from scipy.io import loadmat
import pandas as pd
import numpy as np
data = loadmat('/content/drive/MyDrive/MTECH_PROJECT/s9/s9.mat')

# %%
print(data.keys())
print(type(data))
print(data)

# %%
s2_emg=data['dsfilt_emg']
print(s2_emg)

# %%
section1=(s2_emg[0,0])

# %%
section8=(s2_emg[1,0])

# %%
section15=(s2_emg[2,0])

# %%
section22=(s2_emg[3,0])

# %%
section29=(s2_emg[4,0])

# %%
d1_thumb=np.concatenate((section1,section8,section15,section22,section29),axis=0)
print(d1_thumb.shape)
# Out:
# (20000, 8)

# %%
df1_thumb=pd.DataFrame(d1_thumb)

# %%
df1_thumb.to_csv('/content/drive/MyDrive/MTECH_PROJECT/emg_thumb_s1.csv',index=False)

# %%
section2=(s2_emg[0,1])

# %%
section9=(s2_emg[1,1])

# %%
section16=(s2_emg[2,1])

# %%
section23=(s2_emg[3,1])

# %%
section30=(s2_emg[4,1])

# %%
d1_index=np.concatenate((section2,section9,section16,section23,section30),axis=0)
print(d1_index.shape)
# Out:
# (20000, 8)

# %%
df1_index=pd.DataFrame(d1_index)

# %%
df1_index.to_csv('/content/drive/MyDrive/MTECH_PROJECT/emg_index_s1.csv',index=False)

# %%
section3=(s2_emg[0,2])

# %%
section10=(s2_emg[1,2])

# %%
section17=(s2_emg[2,2])

# %%
section24=(s2_emg[3,2])

# %%
section31=(s2_emg[4,2])

# %%
d1_middle=np.concatenate((section3,section10,section17,section24,section31),axis=0)
print(d1_middle.shape)
# Out:
# (20000, 8)

# %%
df1_middle=pd.DataFrame(d1_middle)

# %%
df1_middle.to_csv('/content/drive/MyDrive/MTECH_PROJECT/emg_middle_s1.csv',index=False)

# %%
section4=(s2_emg[0,3])

# %%
section11=(s2_emg[1,3])

# %%
section18=(s2_emg[2,3])

# %%
section25=(s2_emg[3,3])

# %%
section32=(s2_emg[4,3])

# %%
d1_ring=np.concatenate((section4,section11,section18,section25,section32),axis=0)
print(d1_ring.shape)
# Out:
# (20000, 8)

# %%
df1_ring=pd.DataFrame(d1_ring)

# %%
df1_ring.to_csv('/content/drive/MyDrive/MTECH_PROJECT/emg_ring_s1.csv',index=False)

# %%
section5=(s2_emg[0,4])

# %%
section12=(s2_emg[1,4])

# %%
section19=(s2_emg[2,4])

# %%
section26=(s2_emg[3,4])

# %%
section33=(s2_emg[4,4])

# %%
d1_little=np.concatenate((section5,section12,section19,section26,section33),axis=0)
print(d1_little.shape)
# Out:
# (20000, 8)

# %%
df1_little=pd.DataFrame(d1_little)

# %%
df1_little.to_csv('/content/drive/MyDrive/MTECH_PROJECT/emg_little_s1.csv',index=False)

# %%
section6=(s2_emg[0,5])

# %%
section13=(s2_emg[1,5])

# %%
section20=(s2_emg[2,5])

# %%
section27=(s2_emg[3,5])

# %%
section34=(s2_emg[4,5])

# %%
d1_all=np.concatenate((section6,section13,section20,section27,section34),axis=0)
print(d1_all.shape)
# Out:
# (20000, 8)

# %%
df1_all=pd.DataFrame(d1_all)

# %%
df1_all.to_csv('/content/drive/MyDrive/MTECH_PROJECT/emg_all_s1.csv',index=False)

# %%
section7=(s2_emg[0,6])

# %%
section14=(s2_emg[1,6])

# %%
section21=(s2_emg[2,6])

# %%
section28=(s2_emg[3,6])

# %%
section35=(s2_emg[4,6])

# %%
d1_random=np.concatenate((section7,section14,section21,section21,section35),axis=0)
print(d1_random.shape)
# Out:
# (20000, 8)

# %%
df1_random=pd.DataFrame(d1_random)

# %%
df1_random.to_csv('/content/drive/MyDrive/MTECH_PROJECT/emg_random_s1.csv',index=False)
