# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
import statistics

# %%
df1 = pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s8/s8_emg.csv')
print(df1.shape)
df1.head()
# Out:
# (140000, 8)
#           0         1         2         3         4         5         6  \
# 0  0.502137  0.386973  0.328335  0.418734  0.367965  0.505302  0.345100
# 1  0.502153  0.387078  0.328381  0.420023  0.368311  0.507213  0.346158
# 2  0.502169  0.387183  0.328426  0.421306  0.368652  0.509114  0.347214
# 3  0.502185  0.387288  0.328471  0.422580  0.368989  0.511003  0.348268
# 4  0.502201  0.387392  0.328515  0.423844  0.369321  0.512876  0.349318
#
#           7
# 0  0.484805
# 1  0.485316
# 2  0.485823
# 3  0.486323
# 4  0.486816

# %%
df2 = pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s8/s8_Kinematics.csv')
print(df2.shape)
df2.head()
# Out:
# (140000, 69)
#             0          1          2           3          4          5  \
# 0  103.098067 -10.070082  35.730091  104.569022 -17.863357  13.676219
# 1  103.088317 -10.077812  35.743342  104.567290 -17.884612  13.681016
# 2  103.078654 -10.085795  35.756448  104.565536 -17.906028  13.685626
# 3  103.069096 -10.094017  35.769389  104.563763 -17.927572  13.690044
# 4  103.059658 -10.102461  35.782148  104.561974 -17.949213  13.694264
#
#             6          7         8           9  ...         59         60  \
# 0  104.292819 -12.562171 -2.786954  103.046939  ...  10.880538  29.435564
# 1  104.292233 -12.570693 -2.775610  103.048175  ...  10.885918  29.440251
# 2  104.291721 -12.579330 -2.764364  103.049432  ...  10.891274  29.444956
# 3  104.291287 -12.588070 -2.753231  103.050710  ...  10.896597  29.449675
# 4  104.290936 -12.596899 -2.742224  103.052011  ...  10.901880  29.454404
#
#           61         62         63        64         65        66        67  \
# ...

# %%
#####nan value check
df1.dropna(inplace=True)
df2.dropna(inplace=True)

# %%
#####input data partition
X_train, X_test, y_train, y_test = train_test_split(df1, df2, train_size=0.70, random_state=42)

print(f' Training input data size: {X_train.shape}')
print(f' Test input data size: {X_test.shape}')
print(f' Training output data size: {y_train.shape}')
print(f' Test output data size: {y_test.shape}')
# Out:
#  Training input data size: (98000, 8)
#  Test input data size: (42000, 8)
#  Training output data size: (98000, 69)
#  Test output data size: (42000, 69)

# %%
#####KNN regression
knn = KNeighborsRegressor()
start1=time.time()
knn.fit(X_train,y_train)
end1=time.time()
# print("time taken1: ",(end1-start1)/98000)
y_pred_train = knn.predict(X_train)
start2=time.time()
y_pred_test = knn.predict(X_test)
end2=time.time()
# print("time taken2: ",(end2-start2)/42000)
knn_accuracy = pd.DataFrame({
    'Parameters': ['R2_train','RMSE_train','R2_test','RMSE_test','time taken1','time taken2'],
    'knn': [ r2_score(y_train,y_pred_train),mean_squared_error(y_train,y_pred_train,squared=False), 
                 r2_score(y_test,y_pred_test),mean_squared_error(y_test,y_pred_test,squared=False),(end1-start1)/98000,(end2-start2)/42000]})
# knn_accuracy=knn_accuracy.transpose()
print(knn_accuracy)
# print("time taken: ",end-start)
# Out:
#     Parameters       knn
# 0     R2_train  0.999216
# 1   RMSE_train  0.321858
# 2      R2_test  0.998335
# 3    RMSE_test  0.472548
# 4  time taken1  0.000003
# 5  time taken2  0.000018

# %%
y_pred_train.shape
# Out:
# (98000, 69)

# %%
y_pred_test.shape
# Out:
# (42000, 69)
