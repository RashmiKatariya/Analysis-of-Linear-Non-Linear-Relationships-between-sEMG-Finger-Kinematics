# %%
#Chat_GPT
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load your data
train_data1 = pd.read_csv('train_data1.csv')
train_data2 = pd.read_csv('train_data2.csv')
val_data1 = pd.read_csv('val_data1.csv')
val_data2 = pd.read_csv('val_data2.csv')

# Concatenate your training and validation data
train_data = pd.concat([train_data1, train_data2])
val_data = pd.concat([val_data1, val_data2])

# Split your data into input features and target variable
X_train = train_data.drop('target', axis=1)
y_train = train_data['target']
X_val = val_data.drop('target', axis=1)
y_val = val_data['target']

# Split your data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train your random forest regressor on the training set
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate your model on the validation set
y_pred = model.predict(X_val)
mse = mean_squared_error(y_val, y_pred)
print('Mean squared error:', mse)

# %%
#My modifications

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load your data
train_data1 = pd.read_csv('leave10E.csv')
train_data2 = pd.read_csv('leave10K.csv')
val_data1 = pd.read_csv('s1_emg.csv')
val_data2 = pd.read_csv('s1_kinematic.csv')

# Concatenate your training and validation data
train_data = pd.concat([train_data1, train_data2])
val_data = pd.concat([val_data1, val_data2])

# # Split your data into input features and target variable
# X_train = train_data.drop('target', axis=1)
# y_train = train_data['target']
# X_val = val_data.drop('target', axis=1)
# y_val = val_data['target']

# Split your data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(train_data,val_data, test_size=0.2, random_state=42)

# Train your random forest regressor on the training set
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate your model on the validation set
y_pred = model.predict(X_val)
mse = mean_squared_error(y_val, y_pred)
print('Mean squared error:', mse)

# %%
##chatgpt :
#There is no target column in my dataset as it is for reggression
#In that case, you don't need to drop any columns from your dataframes since you don't have a target column. Here's 
#how you can modify the code to split the data into training and validation sets without specifying the target variable:

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load your data
train_data1 = pd.read_csv('train_data1.csv')
train_data2 = pd.read_csv('train_data2.csv')
val_data1 = pd.read_csv('val_data1.csv')
val_data2 = pd.read_csv('val_data2.csv')

# Concatenate your training and validation data
train_data = pd.concat([train_data1, train_data2])
val_data = pd.concat([val_data1, val_data2])

# Split your data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(pd.concat([train_data, val_data]), pd.concat([train_data, val_data])['target'], test_size=0.2, random_state=42)

# Train your random forest regressor on the training set
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate your model on the validation set
y_pred = model.predict(X_val)
mse = mean_squared_error(y_val, y_pred)
print('Mean squared error:', mse)
