# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df1=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s1/s1_Kinematics.csv')
df2=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s2/s2_Kinematics.csv')
df3=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s3/s3_Kinematics.csv')
df4=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s4/s4_Kinematics.csv')
df5=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s5/s5_Kinematics.csv')
df6=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s6/s6_Kinematics.csv')
# df7=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s7/s7_Kinematics.csv')
df8=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s8/s8_Kinematics.csv')
df9=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s9/s9_Kinematics.csv')
df10=pd.read_csv('/content/drive/MyDrive/MTECH_PROJECT/s10/s10_Kinematics.csv')

BigDf=pd.concat([df1,df2,df3,df4,df5,df6,df8,df9,df10],axis=0)
BigDf.shape
# Out:
# (1259999, 138)

# %%
BigDf.to_csv("/content/drive/MyDrive/MTECH_PROJECT/leave7K.csv",index=False)
